# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
plt.style.use('./deeplearning.mplstyle')
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.activations import linear, relu, sigmoid
# %matplotlib inline
# %matplotlib widget
from matplotlib.widgets import Slider
from lab_utils_common import dlc
from autils import plt_act_trio
from lab_utils_relu import *
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# <a name="2"></a>
# ## 2 - ReLU 激活
# 本周介绍了一种新的激活函数——修正线性单元（ReLU）。
# $$ a = max(0,z) \quad\quad\text {# ReLU function} $$

# %%
plt_act_trio()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# <img align="right" src="../work/images/C2_W2_ReLu.png"     style=" width:380px; padding: 10px 20px; " >
# 右侧的课程示例展示了 ReLU 的一种应用。在这个示例中，派生出的“认知度”特征不是二值的，而是具有连续的取值范围。sigmoid 最适合开／关或二值情形；ReLU 则提供连续的线性关系，并且还有一个输出为零的“关闭”区间。
# 这个“关闭”特征使 ReLU 成为非线性激活函数。为什么需要非线性？下面来研究这个问题。

# %% [markdown]
# ### 为什么需要非线性激活？
# <img align="left" src="../work/images/C2_W2_ReLU_Graph.png"     style=" width:250px; padding: 10px 20px; " > 所示函数由线性片段组成（分段线性）。在线性区段内斜率保持不变，在过渡点处则突然改变。在过渡点，会加入一个新的线性函数；它与现有函数相加后产生新的斜率。新函数在过渡点加入，但在过渡点之前不会对输出产生贡献。非线性激活函数负责在过渡点之前、有时也在过渡点之后禁用输入。下面的练习会给出一个更直观的示例。

# %% [markdown]
# 本练习将使用下面的网络解决一个回归问题，你必须对分段线性目标进行建模：
# <img align="center" src="../work/images/C2_W2_ReLU_Network.png"     style=" width:650px; padding: 10px 20px; ">
# 该网络的第一层有 3 个单元，每个单元负责目标的一段。单元 0 已预先编程并固定，用于映射第一段。你将修改单元 1 和 2 的权重与偏置，对第二段和第三段建模。输出单元同样固定，只是将第一层的输出相加。
#
# 使用下面的滑块修改权重和偏置，使其与目标匹配。
# 提示：从 `w1` 和 `b1` 开始，在匹配第二段之前让 `w2` 和 `b2` 保持为零。点击比拖动更快。如果遇到困难，也不用担心，下面的文字会更详细地说明。

# %%
_ = plt_relu_ex()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
#
# 本练习的目标，是理解 ReLU 的非线性行为如何提供一种必需的能力：在函数需要发挥作用之前将其关闭。让我们看看它在本示例中如何工作。
# <img align="right" src="../work/images/C2_W2_ReLU_Plot.png"     style=" width:600px; padding: 10px 20px; ">
# 右侧的图包含第一层中各单元的输出。
# 从顶部开始，单元 0 负责标记为 1 的第一个线段。图中同时显示了线性函数 $z$ 和经过 ReLU 后的函数 $a$。可以看到，ReLU 在区间 [0,1] 之后截断了该函数。这一点很关键，因为它可以防止该函数干扰后续线段。
#
# 单元 1 负责第 2 个线段。在这里，ReLU 使该单元在 x 大于 1 之前一直保持静默。由于第一个单元没有贡献，单元 1 的斜率 $w^{[1]}_1$ 就是目标直线的斜率。必须调整偏置，使输出在 x 达到 1 之前一直为负。
#
# 单元 2 负责第 3 个线段。ReLU 再次将输出置零，直到 x 达到正确的值。必须设置该单元的斜率 $w^{[1]}_2$，使单元 1 和 2 的斜率之和达到所需斜率。偏置同样需要调整，使输出在 x 达到 2 之前一直为负。
#
# ReLU 激活函数的“关闭”或禁用特性，使模型能够将多个线性线段拼接起来，对复杂的非线性函数进行建模。

# %% [markdown]
# # =======新内容结束===

# %% [markdown]
# ## 新激活函数
# 本周介绍了一种新的激活函数，即修正线性单元（ReLU）。

# %%
def plt_act_trio():
    X = np.linspace(-5,5,100)
    fig,ax = plt.subplots(1,3, figsize=(6,2))
    widgvis(fig)
    ax[0].plot(X,tf.keras.activations.linear(X))
    ax[0].axvline(0, lw=0.3, c="black")
    ax[0].axhline(0, lw=0.3, c="black")
    ax[0].set_title("linear")
    ax[1].plot(X,tf.keras.activations.sigmoid(X))
    ax[1].axvline(0, lw=0.3, c="black")
    ax[1].axhline(0, lw=0.3, c="black")
    ax[1].set_title("sigmoid")
    ax[2].plot(X,tf.keras.activations.relu(X))
    ax[2].axhline(0, lw=0.3, c="black")
    ax[2].axvline(0, lw=0.3, c="black")
    ax[2].set_title("relu")
    fig.suptitle("Common Activation Functions", fontsize=14)
    fig.tight_layout(pad=0.2)
    plt.show()
plt_act_trio()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# <right images>
#     右侧示例展示了 ReLU 的一种应用。在该示例中，“认知度”特征并非二元特征，而是具有从 0 到较大值的变化范围。sigmoid 最适合开/关或二元情形。ReLU 提供线性关系，同时还有一段输出为零的“关闭”区间。这个“关闭”特征使 ReLU 成为非线性激活函数。为什么需要它？让我们通过下面的示例进行研究。

# %%
X = np.linspace(0,2*np.pi, 100)
y = np.cos(X)+1
y[50:100]=0
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
w10 = np.array([[-1]])
b10 = np.array([2.6])
#d10 = Dense(1, activation = "linear", input_shape = (1,), weights=[w10,b10])
d10 = Dense(1, activation="linear")

_ = d10(X.reshape(-1, 1))   # 第一次调用，创建 w 和 b
d10.set_weights([w10, b10])

z10 = d10(X.reshape(-1,1))
a10 = relu(z10)

# %%
def plt_act1(y,z,a):
    fig,ax = plt.subplots(1,3, figsize=(6,2.5))
    widgvis(fig)
    ax[0].plot(X,y,label="target")
    ax[0].axvline(0, lw=0.3, c="black")
    ax[0].axhline(0, lw=0.3, c="black")
    ax[0].set_title("y - target")
    ax[1].plot(X,y, label="target")
    ax[1].plot(X,z, c=dlc["dldarkred"],label="z")
    ax[1].axvline(0, lw=0.3, c="black")
    ax[1].axhline(0, lw=0.3, c="black")
    ax[1].set_title("z = wX+b")
    ax[1].legend(loc="upper center")
    ax[2].plot(X,y, label="target")
    ax[2].plot(X,a, c=dlc["dldarkred"],label="ReLu(z)")
    ax[2].axhline(0, lw=0.3, c="black")
    ax[2].axvline(0, lw=0.3, c="black")
    ax[2].set_title("with relu")
    ax[2].legend()
    fig.suptitle("Role of Activation", fontsize=14)
    fig.tight_layout(pad=0.2)
    return(ax)


def plt_add_notation(ax):
    ax[1].annotate(text = "matches\n here", xy =(1.5,1.0), 
                   xytext = (0.1,-1.5), fontsize=10,
                  arrowprops=dict(facecolor=dlc["dlpurple"],width=2, headwidth=8))
    ax[1].annotate(text = "but not\n here", xy =(5,-2.5), 
                   xytext = (1,-3), fontsize=10,
                  arrowprops=dict(facecolor=dlc["dlpurple"],width=2, headwidth=8))
    ax[2].annotate(text = "ReLu\n 'off'", xy =(2.6,0), 
                   xytext = (0.1,0.1), fontsize=10,
                  arrowprops=dict(facecolor=dlc["dlpurple"],width=2, headwidth=8))
    
ax = plt_act1(y,z10,a10)
plt_add_notation(ax)

# %%
X = np.linspace(0,2*np.pi, 100)
y = np.cos(X)+1
y[0:49]=0
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
w11 = np.array([[1]])
b11 = np.array([-3.7])
#d11 = Dense(1, activation = "linear", input_shape = (1,), weights=[w11,b11])
d11 = Dense(1, activation="linear")

_ = d11(X.reshape(-1, 1))   # 第一次调用，创建 w 和 b
d11.set_weights([w11, b11])

z11 = d11(X.reshape(-1,1))
a11 = relu(z11)
plt_act1(y,z11,a11)
# Out:
# array([<Axes: title={'center': 'y - target'}>,
#        <Axes: title={'center': 'z = wX+b'}>,
#        <Axes: title={'center': 'with relu'}>], dtype=object)

# %%
X = np.linspace(0,2*np.pi, 100)
y = np.cos(X)+1
X=X.reshape(-1,1)
yhat = relu(d10(X)) + relu(d11(X))

fig,ax = plt.subplots(1,2, figsize=(4,2))
widgvis(fig)
ax[0].plot(X,y)
ax[1].plot(X,y)
ax[1].plot(X,yhat)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
X=X.reshape(-1,1)
yhat = relu(d10(X)) + relu(d11(X))
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
ax.plot(X,yhat)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
yhat = model.predict(X.reshape(-1,1))
fig,ax = plt.subplots(1,1, figsize=(2,2))
widgvis(fig)
ax.plot(X,y)
ax.plot(X,yhat)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
model = Sequential(
    [ 
        d10,
        tf.layers.Activation(activations.relu),
        d11,
        tf.layers.Activation(activations.relu),
        Dense(1, activation = 'linear')
    ]
)
model.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=tf.keras.optimizers.Adam(0.1),
)

model.fit(
    X,y,
    epochs=1000
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 4
#       1 model = Sequential(
#       2     [
#       3         d10,
# ----> 4         tf.layers.Activation(activations.relu),
#       5         d11,
#       6         tf.layers.Activation(activations.relu),
#       7         Dense(1, activation = 'linear')
#
# AttributeError: module 'tensorflow' has no attribute 'layers'

# %%
model = Sequential(
    [ 
        Dense(1,activation="relu", name = 'l1'),
        Dense(1,activation="linear", name = 'l2')
    ]
)
model.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X,y,
    epochs=10
)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.7581
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7313
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7097
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6873
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6658
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6502
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6342
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6238
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6162
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6090

# %%
yhat = model.predict(X)
yhat[0:5]
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# array([[0.38],
#        [0.39],
#        [0.4 ],
#        [0.41],
#        [0.42]], dtype=float32)

# %%
fig,ax = plt.subplots(1,1, figsize=(4,4))
ax.plot(X,y)
ax.plot(X,yhat, c=dlc["dldarkred"])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
l1 = model.get_layer('l1')
l2 = model.get_layer('l2')

# %%
l1.get_weights()
# Out:
# [array([[0.28]], dtype=float32), array([0.25], dtype=float32)]

# %%
l2.get_weights()
# Out:
# [array([[0.51]], dtype=float32), array([0.25], dtype=float32)]

# %%
l1 = model.get_layer('l1')
l2 = model.get_layer('l2')
l1.get_weights()
l2.get_weights()

w1 = np.array([[-1]])
b1 = np.array([1])
l1.set_weights([w1,b1])

w2 = np.array([[1]])
b2 = np.array([0])
l2.set_weights([w2,b2])
model.fit(
    X,y,
    epochs=100
)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2517
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1922
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1050
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0147
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9217
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8343
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7541
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6827
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6154
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5616
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5178
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4814
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4528
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4276
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4083
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3947
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3823
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3745
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3695
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3652
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3632
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3609
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3596
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3582
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3570
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3562
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3554
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3543
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3537
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3528
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3521
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3512
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3506
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3504
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3497
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3494
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3492
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3490
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3487
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3484
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3483
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3482
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3481
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3481
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3480
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3479
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3479
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3478
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3474
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3472
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3472
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3472
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3471
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3471
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3470
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3470
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3471
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3470
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3470
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3469
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3469
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3469
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3467
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3467
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3467
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3467
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3465
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3466
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3465
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3466
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3468
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3466
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3466
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3474
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3468
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3469
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3468
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3468
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3467
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3465
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3464
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3466
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3468
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3468
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3468
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3467
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3468
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3469
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3469
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3465
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3467
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3465
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3468
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3470
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3471

# %%
l2.set_weights([w2,b2])

# %%
yhat = model.predict(X)
fig,ax = plt.subplots(1,1, figsize=(4,4))
ax.plot(X,y)
ax.plot(X,yhat, c=dlc["dldarkred"])
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## 2-D

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import warnings
from matplotlib import cm
from matplotlib.patches import FancyArrowPatch
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib.colors as colors
from lab_utils_common import dlc
dkcolors = plt.cm.Paired((1,3,7,9,5,11))
ltcolors = plt.cm.Paired((0,2,6,8,4,10))
dkcolors_map = mpl.colors.ListedColormap(dkcolors)
ltcolors_map = mpl.colors.ListedColormap(ltcolors)

# %%
def plt_mc_data(ax, X, y, classes,  class_labels=None, map=plt.cm.Paired, 
                legend=False, size=50, m='o', equal_xy = False):
    """ Plot multiclass data. Note, if equal_xy is True, setting ylim on the plot may not work """
    for i in range(classes):
        idx = np.where(y == i)
        col = len(idx[0])*[i]
        label = class_labels[i] if class_labels else "c{}".format(i)
        ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
                    c=col, vmin=0, vmax=map.N, cmap=map,
                    s=size, label=label)
    if legend: ax.legend()
    if equal_xy: ax.axis("equal")

def plt_mc(X_train,y_train,classes):
    css = np.unique(y_train)
    fig,ax = plt.subplots(1,1,figsize=(3,3))
    fig.canvas.toolbar_visible = False
    fig.canvas.header_visible = False
    fig.canvas.footer_visible = False
    plt_mc_data(ax, X_train,y_train,classes, map=dkcolors_map, legend=True, size=10, equal_xy = False)
    ax.set_title("Multiclass Data")
    ax.set_xlabel("x0")
    ax.set_ylabel("x1")
    return(ax)
    
def plot_cat_decision_boundary_mc(ax, X, predict , class_labels=None, legend=False, vector=True):

    # create a mesh to points to plot
    x_min, x_max = X[:, 0].min(), X[:, 0].max()
    y_min, y_max = X[:, 1].min(), X[:, 1].max()
    h = max(x_max-x_min, y_max-y_min)/200
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    points = np.c_[xx.ravel(), yy.ravel()]
    #print("points", points.shape)
    #print("xx.shape", xx.shape)

    #make predictions for each point in mesh
    if vector:
        Z = predict(points)
    else:
        Z = np.zeros((len(points),))
        for i in range(len(points)):
            Z[i] = predict(points[i].reshape(1,2))
    Z = Z.reshape(xx.shape)

    #contour plot highlights boundaries between values - classes in this case
    ax.contour(xx, yy, Z, linewidths=1) 
    #ax.axis('tight')

# %%
X = np.random.rand(300, 2)
y = np.sqrt( X[:,0]**2 + X[:,1]**2 ) < 0.6
#y = np.logical_and( X[:,0] < 0.5, X[:,1] < 0.5 ).astype(int)
y.shape
plt_mc(X,y,2,)
# Out:
# <Axes: title={'center': 'Multiclass Data'}, xlabel='x0', ylabel='x1'>
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
model = Sequential(
    [ 
        Dense(2,activation="relu",    name = 'l1'),
        Dense(1,activation="sigmoid", name = 'l2')
    ]
)

model.compile(
    loss=tf.keras.losses.MeanSquaredError(),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X,y,
    epochs=150
)
# Out:
# Epoch 1/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3172
# Epoch 2/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2746
# Epoch 3/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2430
# Epoch 4/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2292
# Epoch 5/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2217
# Epoch 6/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2138
# Epoch 7/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2056
# Epoch 8/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2006
# Epoch 9/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1956
# Epoch 10/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1901
# Epoch 11/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1830
# Epoch 12/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1758
# Epoch 13/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1681
# Epoch 14/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1607
# Epoch 15/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1533
# Epoch 16/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1462
# Epoch 17/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1395
# Epoch 18/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1331
# Epoch 19/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1278
# Epoch 20/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1224
# Epoch 21/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1177
# Epoch 22/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1125
# Epoch 23/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1085
# Epoch 24/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1042
# Epoch 25/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1005
# Epoch 26/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0967
# Epoch 27/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0934
# Epoch 28/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0903
# Epoch 29/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0876
# Epoch 30/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0849
# Epoch 31/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0827
# Epoch 32/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0807
# Epoch 33/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0784
# Epoch 34/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0765
# Epoch 35/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0744
# Epoch 36/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0729
# Epoch 37/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0715
# Epoch 38/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0699
# Epoch 39/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0688
# Epoch 40/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0676
# Epoch 41/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0663
# Epoch 42/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0651
# Epoch 43/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0644
# Epoch 44/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0631
# Epoch 45/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0622
# Epoch 46/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0614
# Epoch 47/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0606
# Epoch 48/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0599
# Epoch 49/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0593
# Epoch 50/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0585
# Epoch 51/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0578
# Epoch 52/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0573
# Epoch 53/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0573
# Epoch 54/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0561
# Epoch 55/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0556
# Epoch 56/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0551
# Epoch 57/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0549
# Epoch 58/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0541
# Epoch 59/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0540
# Epoch 60/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0536
# Epoch 61/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0532
# Epoch 62/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0530
# Epoch 63/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0526
# Epoch 64/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0521
# Epoch 65/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0517
# Epoch 66/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0513
# Epoch 67/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0513
# Epoch 68/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0508
# Epoch 69/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0507
# Epoch 70/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0510
# Epoch 71/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0499
# Epoch 72/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0501
# Epoch 73/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0501
# Epoch 74/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0498
# Epoch 75/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496
# Epoch 76/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0490
# Epoch 77/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489
# Epoch 78/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486
# Epoch 79/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0484
# Epoch 80/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0483
# Epoch 81/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0482
# Epoch 82/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0484
# Epoch 83/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0479
# Epoch 84/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0477
# Epoch 85/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0474
# Epoch 86/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0478
# Epoch 87/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0473
# Epoch 88/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0471
# Epoch 89/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0472
# Epoch 90/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0471
# Epoch 91/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0468
# Epoch 92/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0469
# Epoch 93/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0467
# Epoch 94/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466
# Epoch 95/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466
# Epoch 96/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0462
# Epoch 97/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0460
# Epoch 98/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0461
# Epoch 99/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0457
# Epoch 100/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0462
# Epoch 101/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0458
# Epoch 102/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0460
# Epoch 103/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466
# Epoch 104/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0454
# Epoch 105/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0453
# Epoch 106/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0453
# Epoch 107/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0451
# Epoch 108/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0448
# Epoch 109/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0452
# Epoch 110/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0450
# Epoch 111/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0447
# Epoch 112/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0448
# Epoch 113/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0448
# Epoch 114/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0451
# Epoch 115/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0446
# Epoch 116/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0446
# Epoch 117/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0446
# Epoch 118/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0446
# Epoch 119/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443
# Epoch 120/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0442
# Epoch 121/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0445
# Epoch 122/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0447
# Epoch 123/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0438
# Epoch 124/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0449
# Epoch 125/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0440
# Epoch 126/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0444
# Epoch 127/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0442
# Epoch 128/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0440
# Epoch 129/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0439
# Epoch 130/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0439
# Epoch 131/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0437
# Epoch 132/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0440
# Epoch 133/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0439
# Epoch 134/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443
# Epoch 135/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0438
# Epoch 136/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0436
# Epoch 137/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0434
# Epoch 138/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0438
# Epoch 139/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0440
# Epoch 140/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0435
# Epoch 141/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0434
# Epoch 142/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0441
# Epoch 143/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0431
# Epoch 144/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0440
# Epoch 145/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0435
# Epoch 146/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0437
# Epoch 147/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432
# Epoch 148/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0432
# Epoch 149/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432
# Epoch 150/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0431

# %%
ax = plt_mc(X,y,2,)
predict = lambda  x: (model.predict(x) > 0.5).astype(int)
plot_cat_decision_boundary_mc(ax, X, predict, legend = True, vector=True)
# Out:
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 1s 755us/step

# %%
l1 = model.get_layer("l1")
W1,b1 = l1.get_weights()
l2 = model.get_layer("l2")
W2,b2 = l2.get_weights()
print(W1,b1)
print(W2,b2)

# %%
x0 = np.array([0.4,0.60])
np.dot( np.dot(x0,W1) + b1, W2) + b2

# %%
## Example

# %%
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)

# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# ============
# Set up cluster parameters
# ============
plt.figure(figsize=(9 * 2 + 3, 13))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.05, hspace=0.01
)

plot_num = 1

default_base = {
    "quantile": 0.3,
    "eps": 0.3,
    "damping": 0.9,
    "preference": -200,
    "n_neighbors": 3,
    "n_clusters": 3,
    "min_samples": 7,
    "xi": 0.05,
    "min_cluster_size": 0.1,
}

datasets = [
    (
        noisy_circles,
        {
            "damping": 0.77,
            "preference": -240,
            "quantile": 0.2,
            "n_clusters": 2,
            "min_samples": 7,
            "xi": 0.08,
        },
    ),
    (
        noisy_moons,
        {
            "damping": 0.75,
            "preference": -220,
            "n_clusters": 2,
            "min_samples": 7,
            "xi": 0.1,
        },
    ),
    (
        varied,
        {
            "eps": 0.18,
            "n_neighbors": 2,
            "min_samples": 7,
            "xi": 0.01,
            "min_cluster_size": 0.2,
        },
    ),
    (
        aniso,
        {
            "eps": 0.15,
            "n_neighbors": 2,
            "min_samples": 7,
            "xi": 0.1,
            "min_cluster_size": 0.2,
        },
    ),
    (blobs, {"min_samples": 7, "xi": 0.1, "min_cluster_size": 0.2}),
    (no_structure, {}),
]

datasets = [
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # normalize dataset for easier parameter selection
    X = StandardScaler().fit_transform(X)

    # estimate bandwidth for mean shift
    bandwidth = cluster.estimate_bandwidth(X, quantile=params["quantile"])

    # connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params["n_neighbors"], include_self=False
    )
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)

    # ============
    # Create cluster objects
    # ============
    ms = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=True)
    two_means = cluster.MiniBatchKMeans(n_clusters=params["n_clusters"])
    ward = cluster.AgglomerativeClustering(
        n_clusters=params["n_clusters"], linkage="ward", connectivity=connectivity
    )
    spectral = cluster.SpectralClustering(
        n_clusters=params["n_clusters"],
        eigen_solver="arpack",
        affinity="nearest_neighbors",
    )
    dbscan = cluster.DBSCAN(eps=params["eps"])
    optics = cluster.OPTICS(
        min_samples=params["min_samples"],
        xi=params["xi"],
        min_cluster_size=params["min_cluster_size"],
    )
    affinity_propagation = cluster.AffinityPropagation(
        damping=params["damping"], preference=params["preference"], random_state=0
    )
    average_linkage = cluster.AgglomerativeClustering(
        linkage="average",
        affinity="cityblock",
        n_clusters=params["n_clusters"],
        connectivity=connectivity,
    )
    birch = cluster.Birch(n_clusters=params["n_clusters"])
    gmm = mixture.GaussianMixture(
        n_components=params["n_clusters"], covariance_type="full"
    )

    clustering_algorithms = (
        ("MiniBatch\nKMeans", two_means),
        ("Affinity\nPropagation", affinity_propagation),
        ("MeanShift", ms),
        ("Spectral\nClustering", spectral),
        ("Ward", ward),
        ("Agglomerative\nClustering", average_linkage),
        ("DBSCAN", dbscan),
        ("OPTICS", optics),
        ("BIRCH", birch),
        ("Gaussian\nMixture", gmm),
    )

    for name, algorithm in clustering_algorithms:
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the "
                + "connectivity matrix is [0-9]{1,2}"
                + " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning,
            )
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding"
                + " may not work as expected.",
                category=UserWarning,
            )
            print(X.shape,algorithm)
            algorithm.fit(X)

        t1 = time.time()
        if hasattr(algorithm, "labels_"):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(
            list(
                islice(
                    cycle(
                        [
                            "#377eb8",
                            "#ff7f00",
                            "#4daf4a",
                            "#f781bf",
                            "#a65628",
                            "#984ea3",
                            "#999999",
                            "#e41a1c",
                            "#dede00",
                        ]
                    ),
                    int(max(y_pred) + 1),
                )
            )
        )
        # add black color for outliers (if any)
        colors = np.append(colors, ["#000000"])
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.text(
            0.99,
            0.01,
            ("%.2fs" % (t1 - t0)).lstrip("0"),
            transform=plt.gca().transAxes,
            size=15,
            horizontalalignment="right",
        )
        plot_num += 1

plt.show()
