# %% [markdown]
# # 不评分实验：过拟合
#
# <img align="left" src="../work/images/C1_W3_Overfitting_a.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="../work/images/C1_W3_Overfitting_b.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="../work/images/C1_W3_Overfitting_c.png"     style=" width:250px; padding: 10px; " >

# %% [markdown]
# ## 目标
# 在本实验中，你将探索：
# - 可能发生过拟合的情形
# - 一些解决方案

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import Output
from plt_overfit import overfit_example, output
plt.style.use('./deeplearning.mplstyle')
# %pip install -U ipympl ipywidgets
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 过拟合
# 本周课程讲解了可能出现过拟合的情形。运行下面的单元格生成一幅图，以便探索过拟合。单元格下方还有进一步说明。

# %%
plt.close("all")
display(output)
ofit = overfit_example(False)
# Out:
# Output()
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# 在上图中，你可以：
# - 在回归和分类示例之间切换
# - 添加数据
# - 选择模型的次数
# - 将模型拟合到数据
#
# 下面是一些你应尝试的操作：
# - 使用次数 = 1 拟合数据；观察“欠拟合”。
# - 使用次数 = 6 拟合数据；观察“过拟合”
# - 调整次数以获得“最佳拟合”
# - 添加数据：
#     - 极端样本会加剧过拟合（假设它们是离群值）。
#     - 常规样本可以减少过拟合
# - 在 `Regression` 和 `Categorical` 之间切换，尝试这两个示例。
#
# 要重置图，请重新运行该单元格。请缓慢单击，以便在收到下一次单击之前完成图形更新。
#
# 实现说明：
# - “理想”曲线表示生成器模型，数据集是在其基础上添加噪声得到的
# - 为了提高速度，“拟合”并未使用纯梯度下降。对于较小的数据集，可以使用这些方法。

# %% [markdown]
# ## 恭喜！
# 您已经对过拟合的原因及解决方法形成了一些直观认识。在下一个实验中，您将探索一种常用的解决方案：正则化。
