# %% [markdown]
# # 可选实验：逻辑回归与逻辑损失
#
# 在这个不计分的实验中，你将：
# - 探索平方误差损失不适用于逻辑回归的原因
# - 探索逻辑损失函数

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
plt.rcParams['font.size'] = 8
from plt_logistic_loss import  plt_logistic_cost, plt_two_logistic_loss_curves, plt_simple_example
from plt_logistic_loss import soup_bowl, plt_logistic_squared_error

# %% [markdown]
# ## 逻辑回归使用平方误差？
# <img align="left" src="./images/C1_W3_SqErrorVsLogistic.png"     style=" width:400px; padding: 10px; " > 在线性回归中，本课程使用平方误差代价来衡量模型对训练数据的预测效果。
# 回顾一下，对于**线性回归**，你使用了**平方误差代价函数**：
# 单变量平方误差代价的公式为：
#   $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2 \tag{1}$$
#
# 其中
#   $$f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{2}$$

# %% [markdown]
# 回想一下，平方误差代价有一个很好的性质：沿着代价的导数方向前进会到达最小值。

# %%
soup_bowl()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 这个代价函数在线性回归中效果良好，因此很自然也会考虑将它用于逻辑回归。然而，正如上面的幻灯片指出的，$f_{wb}(x)$ 现在包含一个非线性部分，即 sigmoid 函数：$f_{w,b}(x^{(i)}) = sigmoid(wx^{(i)} + b )$。现在，让我们在此前实验的示例上尝试平方误差代价，并加入 sigmoid。
#
# 以下是我们的训练数据：

# %%
x_train = np.array([0., 1, 2, 3, 4, 5],dtype=np.longdouble)
y_train = np.array([0,  0, 0, 1, 1, 1],dtype=np.longdouble)
plt_simple_example(x_train, y_train)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 现在，让我们使用*平方误差代价*绘制代价曲面图：
#   $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2 $$
#
# 其中
#   $$f_{w,b}(x^{(i)}) = sigmoid(wx^{(i)} + b )$$

# %%
plt.close('all')
plt_logistic_squared_error(x_train,y_train)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 虽然这会生成一个颇有意思的图，但上面的曲面远没有线性回归中的“汤碗”那么平滑！
#
# 逻辑回归需要一个更适合其非线性性质的代价函数。这要从损失函数说起，下面将对此进行说明。

# %% [markdown]
# ## 逻辑损失函数
# <img align="left" src="./images/C1_W3_LogisticLoss_a.png"     style=" width:250px; padding: 2px; " >
# <img align="left" src="./images/C1_W3_LogisticLoss_b.png"     style=" width:250px; padding: 2px; " >
# <img align="left" src="./images/C1_W3_LogisticLoss_c.png"     style=" width:250px; padding: 2px; " >

# %% [markdown]
# 逻辑回归使用一种更适合分类任务的损失函数，其中目标值为 0 或 1，而不是任意数值。
#
# >**定义提醒：**
# **损失**衡量单个样本与其目标值之间的差异，而
# **代价**衡量整个训练集上的损失
#
#
# 其定义如下：
# * $loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)})$ 是单个数据点的代价，即：
#
# \begin{equation}
#   loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)}) = \begin{cases}
#     - \log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) & \text{if $y^{(i)}=1$}\\
#     \log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) & \text{if $y^{(i)}=0$}
#   \end{cases}
# \end{equation}
#
#
# * $f_{\mathbf{w},b}(\mathbf{x}^{(i)})$ 是模型的预测，而 $y^{(i)}$ 是目标值。
#
# * $f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = g(\mathbf{w} \cdot\mathbf{x}^{(i)}+b)$，其中函数 $g$ 是 sigmoid 函数。
#
# 该损失函数的定义性特征是它使用了两条不同的曲线：一条对应目标值为零（或 $y=0$）的情况，另一条对应目标值为一（$y=1$）的情况。这两条曲线结合起来，提供了损失函数所需的特性：当预测与目标匹配时值为零，而当预测偏离目标时，其值会迅速增大。请看下面的曲线：

# %%
plt_two_logistic_loss_curves()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 合并后，这些曲线与平方误差损失的二次曲线相似。请注意，x 轴是 $f_{\mathbf{w},b}$，即 sigmoid 的输出。sigmoid 输出严格位于 0 和 1 之间。

# %% [markdown]
# 可以重写上面的损失函数，使其更易于在实现代价计算的程序中使用。
#     $$loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), y^{(i)}) = (-y^{(i)} \log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) - \left( 1 - y^{(i)}\right) \log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right)$$
#
# 这个方程看起来相当复杂。但考虑到 $y^{(i)}$ 只能取 0 和 1 两个值，就没有那么令人生畏了。于是可以将该方程分两种情况考虑：
# 当 $ y^{(i)} = 0$ 时，左侧项被消去：
# $$
# \begin{align}
# loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), 0) &= (-(0) \log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) - \left( 1 - 0\right) \log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) \\
# &= -\log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right)
# \end{align}
# $$
# 当 $ y^{(i)} = 1$ 时，右侧项被消去：
# $$
# \begin{align}
#   loss(f_{\mathbf{w},b}(\mathbf{x}^{(i)}), 1) &=  (-(1) \log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right) - \left( 1 - 1\right) \log \left( 1 - f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right)\\
#   &=  -\log\left(f_{\mathbf{w},b}\left( \mathbf{x}^{(i)} \right) \right)
# \end{align}
# $$
#
# 现在，有了这个新的逻辑损失函数，就可以构造一个包含所有样本损失的代价函数。这将是下一个实验的主题。目前，让我们先看看上面所考虑的简单示例中，代价随参数变化的曲线：

# %%
plt.close('all')
cst = plt_logistic_cost(x_train,y_train)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 这条曲线非常适合梯度下降！它没有平台区、局部最小值或不连续点。请注意，它不像平方误差的情形那样呈碗状。这里同时绘制了代价及其对数，以说明即使代价很小时，曲线仍有斜率并会继续下降。提醒一下：你可以用鼠标旋转上面的图。

# %% [markdown]
# ## 恭喜！
# 你已经：
#  - 确定平方误差损失函数不适合分类任务
#  - 构造并研究了**适合**分类任务的逻辑损失函数。
