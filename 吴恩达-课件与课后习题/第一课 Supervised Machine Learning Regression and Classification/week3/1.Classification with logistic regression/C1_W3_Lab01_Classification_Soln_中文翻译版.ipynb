# %% [markdown]
# # 可选实验：使用逻辑回归进行分类
#
# 在本实验中，你将对比回归与分类。

# %%
import numpy as np
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## 分类问题
# <img align="left" src="../work/images/C1_W3_Classification.png"     style=" width:380px; padding: 10px; " > 分类问题的示例包括：识别电子邮件是垃圾邮件还是非垃圾邮件，或判断肿瘤是恶性还是良性。具体来说，这些都是*二元*分类的示例，即只有两种可能结果。结果可以成对描述为“正”/“负”，例如“是”/“否”、“真”/“假”或“1”/“0”。
#
# 分类数据集的图通常使用符号来表示样本结果。在下图中，“X”表示正值，“O”表示负值。

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

fig,ax = plt.subplots(1,2,figsize=(8,3))
#plot 1, single variable
ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label="y=0", facecolors='none', 
              edgecolors=dlc["dlblue"],lw=3)

ax[0].set_ylim(-0.08,1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#plot 2, two variables
plot_data(X_train2, y_train2, ax[1])
ax[1].axis([0, 4, 0, 4])
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# 请注意上图中的以下几点：
# - 在单变量图中，正类结果同时以红色“X”和 y=1 表示。负类结果以蓝色“O”表示，并位于 y=0。
#    - 回顾一下，在线性回归中，y 不会局限于两个值，而可以取任意值。
# - 在双变量图中，无法显示 y 轴。正类结果用红色“X”表示，负类结果用蓝色“O”表示。
#     - 回顾一下，在多变量线性回归中，y 不会局限于两个值，类似的图将是三维图。

# %% [markdown]
# ## 线性回归方法
# 上一周，你使用线性回归构建了预测模型。现在使用课程中介绍的简单示例尝试这种方法。该模型会根据肿瘤大小预测肿瘤是良性还是恶性。请尝试以下操作：
# - 点击“运行线性回归”，为给定数据寻找最佳线性回归模型。
#     - 请注意，所得线性模型与数据的匹配**并不好**。
# 改进结果的一种方法是应用*阈值*。
# - 勾选“切换 0.5 阈值”复选框，显示应用阈值后的预测。
#     - 这些预测看起来很好，与数据相符
# - *重要*：现在，在最右侧的大肿瘤尺寸范围（接近 10）添加更多“恶性”数据点，并重新运行线性回归。
#     - 现在模型能预测较大的肿瘤，但 x=3 处的数据点被错误预测了！
# - 要清除/刷新图形，请重新运行包含绘图命令的单元格。

# %%
w_in = np.zeros((1))
b_in = 0
plt.close('all') 
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# 上面的示例表明，线性模型不足以对类别数据建模。可以按照下一个实验所述对模型进行扩展。

# %% [markdown]
# ## 恭喜！
# 在本实验中，你：
# - 探索了类别数据集及其绘图
# - 确定了线性回归不足以用于逻辑回归。
