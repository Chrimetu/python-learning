# %% [markdown]
# # 可选实验：Python 和 Jupyter Notebook 简介
# 欢迎参加第一个可选实验！
# 可选实验旨在：
# - 提供信息——就像这个 notebook 一样
# - 通过动手示例巩固课程内容
# - 提供计分实验中所用例程的可运行示例

# %% [markdown]
# ## 目标
# 在本实验中，你将：
# - 简要了解 Jupyter Notebook
# - 浏览 Jupyter Notebook 的功能
# - 了解 Markdown 单元格与代码单元格的区别
# - 练习一些基础 Python

# %% [markdown]
# 熟悉 Jupyter Notebook 最简单的方法，是使用上方“帮助”菜单中提供的导览：

# %% [markdown]
# <figure>
#     <center> <img src="../work/images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Jupyter Notebook 中有两种本课程会用到的单元格。像这个包含说明文档的单元格称为 `Markdown Cells`，其名称源自单元格所使用的简单格式化语言。您无需自己创建 Markdown 单元格，但了解下图所示的 `cell pulldown` 很有帮助。单元格偶尔会处于错误的模式，此时您可能需要将它恢复到正确状态：

# %% [markdown]
# <figure>
#    <img src="../work/images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 另一种单元格是 `code cell`，您将在其中编写代码：

# %%
#This is  a 'Code' Cell
print("This is  code cell")
# Out:
# This is  code cell

# %% [markdown]
# ## Python
# 你可以在代码单元格中编写代码。
# 要运行代码，请选择该单元格，然后执行以下任一操作：
# - 按住 Shift 键并按下“Enter”或“Return”键
# - 单击上方的“运行”箭头
# <figure>
#     <img src="../work/images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### print 语句
# print 语句通常会使用 Python f-string 风格。
# 尝试在下面的单元格中创建自己的 print 语句。
# 试用运行单元格的两种方法。

# %%
# print statements
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # 恭喜！
# 现在，你已经知道如何使用 Jupyter Notebook 了。
