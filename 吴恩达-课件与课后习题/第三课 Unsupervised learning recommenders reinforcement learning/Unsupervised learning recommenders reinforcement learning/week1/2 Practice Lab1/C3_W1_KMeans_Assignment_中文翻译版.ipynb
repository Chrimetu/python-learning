# %% [markdown]
# # K-means 聚类
#
# 在本练习中，你将实现 K-means 算法，并将其用于图像压缩。
#
# * 首先，你将使用一个示例数据集，帮助你直观理解 K-means 算法的工作方式。
# * 随后，你将使用 K-means 算法进行图像压缩，将图像中的颜色数量减少到仅保留其中最常见的颜色。
#
#
#
#
# # 大纲
# - [ 1 - 实现 K-means](#1)
#   - [ 1.1 查找最近的质心](#1.1)
#     - [ 练习 1](#ex01)
#   - [ 1.2 计算质心均值](#1.2)
#     - [ 练习 2](#ex02)
# - [ 2 - 在示例数据集上运行 K-means ](#2)
# - [ 3 - 随机初始化](#3)
# - [ 4 - 使用 K-means 进行图像压缩](#4)
#   - [ 4.1 数据集](#4.1)
#   - [ 4.2 在图像像素上运行 K-means](#4.2)
#   - [ 4.3 压缩图像](#4.3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *

# %matplotlib inline

# %% [markdown]
# <a name="1"></a>
# ## 1 - 实现 K-means
#
# K-means 算法是一种自动将相似数据点聚类到一起的方法。
#
# * 具体而言，给定一个训练集 $\{x^{(1)}, ..., x^{(m)}\}$，你希望将数据分成若干个内聚的“簇”。
#
#
# * K-means 是一个迭代过程，它：
#      * 首先猜测初始质心，然后
#      * 通过以下方式优化该猜测：
#          * 反复将样本分配给距离最近的质心，然后
#          * 根据分配结果重新计算质心。
#
#
# * K-means 算法的伪代码如下：
#
#     ``` python
#     # Initialize centroids
#     # K is the number of clusters
#     centroids = kMeans_init_centroids(X, K)
#
#     for iter in range(iterations):
#         # Cluster assignment step:
#         # Assign each data point to the closest centroid.
#         # idx[i] corresponds to the index of the centroid
#         # assigned to example i
#         idx = find_closest_centroids(X, centroids)
#
#         # Move centroid step:
#         # Compute means based on centroid assignments
#         centroids = compute_means(X, idx, K)
#     ```
#
#
# * 该算法的内层循环反复执行两个步骤：
#     * (i) 将每个训练样本 $x^{(i)}$ 分配给距离最近的质心；以及
#     * (ii) 使用分配给各质心的数据点重新计算每个质心的均值。
#
#
# * $K$-means 算法总会收敛到某一组最终的质心均值。
#
# * 然而，收敛后的解不一定总是理想的，并且取决于质心的初始设置。
#     * 因此，在实践中，通常会使用不同的随机初始化多次运行 K-means 算法。
#     * 从这些不同随机初始化得到的解中进行选择的一种方法，是选择代价函数值（失真）最低的解。
#
# 在接下来的各节中，你将分别实现 K-means 算法的两个阶段。
# * 你将先完成 `find_closest_centroid`，然后继续完成 `compute_centroids`。

# %% [markdown]
# <a name="1.1"></a>
# ### 1.1 查找最近的质心
#
# 在 K-means 算法的“簇分配”阶段，给定质心的当前位置，算法会将每个训练样本 $x^{(i)}$ 分配给距离最近的质心。
#
# <a name="ex01"></a>
# ### 练习 1
#
# 你的任务是完成 `find_closest_centroids` 中的代码。
# * 该函数接收数据矩阵 `X`，以及 `centroids` 中所有质心的位置
# * 它应输出一个一维数组 `idx`（元素数量与 `X` 相同），保存每个训练样本对应的最近质心索引（取值范围为 $\{1,...,K\}$，其中 $K$ 是质心总数）。
# * 具体而言，对于每个样本 $x^{(i)}$，设置：
# $$c^{(i)} := j \quad \mathrm{that \; minimizes} \quad ||x^{(i)} - \mu_j||^2,$$
# 其中：
#  * $c^{(i)}$ 是距离 $x^{(i)}$ 最近的质心索引（对应起始代码中的 `idx[i]`）；并且
#  * $\mu_j$ 是第 $j$ 个质心的位置（值）。（存储在起始代码的 `centroids` 中）
#
# 如果遇到困难，可以查看下方单元格之后给出的提示，以帮助你完成实现。

# %%
# UNQ_C1
# GRADED FUNCTION: find_closest_centroids

def find_closest_centroids(X, centroids):
    """
    Computes the centroid memberships for every example
    
    Args:
        X (ndarray): (m, n) Input values      
        centroids (ndarray): k centroids
    
    Returns:
        idx (array_like): (m,) closest centroids
    
    """

    # Set K
    K = centroids.shape[0]

    # You need to return the following variables correctly
    idx = np.zeros(X.shape[0], dtype=int)

    ### START CODE HERE ###

    ### END CODE HERE ###
    
    return idx

# %% [markdown]
# <details>
#   <summary><font size="3" color="darkgreen"><b>点击查看提示</b></font></summary>
#
#
# * 下面展示了如何组织此函数的整体实现
#     ```python
#     def find_closest_centroids(X, centroids):
#
#         # Set K
#         K = centroids.shape[0]
#
#         # You need to return the following variables correctly
#         idx = np.zeros(X.shape[0], dtype=int)
#
#         ### START CODE HERE ###
#         for i in range(X.shape[0]):
#             # Array to hold distance between X[i] and each centroids[j]
#             distance = []
#             for j in range(centroids.shape[0]):
#                 norm_ij = # Your code to calculate the norm between (X[i] - centroids[j])
#                 distance.append(norm_ij)
#
#             idx[i] = # Your code here to calculate index of minimum value in distance
#         ### END CODE HERE ###
#         return idx
#     ```
#
#     如果仍然没有思路，可以查看下面给出的提示，了解如何计算 `norm_ij` 和 `idx[i]`。
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>计算 norm_ij 的提示</b></font></summary>
#            &emsp; &emsp; 可以使用 <a href="https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html">np.linalg.norm</a> 计算范数
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; 计算 norm_ij 的更多提示</b></font></summary>
#                &emsp; &emsp; 可以按如下方式计算 norm_ij：<code>norm_ij = np.linalg.norm(X[i] - centroids[j]) </code>
#            </details>
#     </details>
#
#      <details>
#           <summary><font size="2" color="darkblue"><b>计算 idx[i] 的提示</b></font></summary>
#           &emsp; &emsp; 可以使用 <a href="https://numpy.org/doc/stable/reference/generated/numpy.argmin.html">np.argmin</a> 找到最小值的索引
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; 计算 idx[i] 的更多提示</b></font></summary>
#               &emsp; &emsp; 可以按如下方式计算 idx[i]：<code>idx[i] = np.argmin(distance)</code>
#           </details>
#     </details>
#
#     </details>
#
# </details>

# %% [markdown]
# 现在，让我们使用一个示例数据集检查你的实现

# %%
# Load an example dataset that we will be using
X = load_data()

# %% [markdown]
# 下面的代码会打印变量 `X` 的前五个元素及该变量的维度

# %%
print("First five elements of X are:\n", X[:5]) 
print('The shape of X is:', X.shape)

# %%
# Select an initial set of centroids (3 Centroids)
initial_centroids = np.array([[3,3], [6,2], [8,5]])

# Find closest centroids using initial_centroids
idx = find_closest_centroids(X, initial_centroids)

# Print closest centroids for the first three elements
print("First three elements in idx are:", idx[:3])

# UNIT TEST
from public_tests import *

find_closest_centroids_test(find_closest_centroids)

# %% [markdown]
# **预期输出**：
# <table>
#   <tr>
#     <td> <b>idx 中的前三个元素是<b></td>
#     <td> [0 2 1] </td>
#   </tr>
# </table>

# %% [markdown]
# <a name="1.2"></a>
# ### 1.2 计算聚类中心均值
#
# 给定每个点对应的聚类中心分配后，算法的第二阶段会重新计算每个聚类中心所分配点的均值。
#
#
# <a name="ex02"></a>
# ### 练习 2
#
# 请完成下面的 `compute_centroids`，重新计算每个聚类中心的值
#
# * 具体来说，对于每个聚类中心 $\mu_k$，设置
# $$\mu_k = \frac{1}{|C_k|} \sum_{i \in C_k} x^{(i)}$$
#
#     其中
#     * $C_k$ 是分配给聚类中心 $k$ 的样本集合
#     * $|C_k|$ 是集合 $C_k$ 中的样本数量
#
#
# * 具体而言，如果两个样本 $x^{(3)}$ 和 $x^{(5)}$ 被分配给聚类中心 $k=2$，
# 则应更新 $\mu_2 = \frac{1}{2}(x^{(3)}+x^{(5)})$。
#
# 如果遇到困难，可以查看下面单元格之后给出的提示来帮助完成实现。

# %%
# UNQ_C2
# GRADED FUNCTION: compute_centpods

def compute_centroids(X, idx, K):
    """
    Returns the new centroids by computing the means of the 
    data points assigned to each centroid.
    
    Args:
        X (ndarray):   (m, n) Data points
        idx (ndarray): (m,) Array containing index of closest centroid for each 
                       example in X. Concretely, idx[i] contains the index of 
                       the centroid closest to example i
        K (int):       number of centroids
    
    Returns:
        centroids (ndarray): (K, n) New centroids computed
    """
    
    # Useful variables
    m, n = X.shape
    
    # You need to return the following variables correctly
    centroids = np.zeros((K, n))
    
    ### START CODE HERE ###

    ### END CODE HERE ## 
    
    return centroids

# %% [markdown]
# <details>
#   <summary><font size="3" color="darkgreen"><b>点击查看提示</b></font></summary>
#
#
# * 此函数的整体实现可以采用以下结构
#     ```python
#     def compute_centroids(X, idx, K):
#         # Useful variables
#         m, n = X.shape
#
#         # You need to return the following variables correctly
#         centroids = np.zeros((K, n))
#
#         ### START CODE HERE ###
#         for k in range(K):
#             points = # Your code here to get a list of all data points in X assigned to centroid k
#             centroids[k] = # Your code here to compute the mean of the points assigned
#     ### END CODE HERE ##
#
#     return centroids
#     ```
#
#     如果仍然遇到困难，可以查看下面的提示，了解如何计算 `points` 和 `centroids[k]`。
#
#     <details>
#           <summary><font size="2" color="darkblue"><b>计算 points 的提示</b></font></summary>
#            &emsp; &emsp; 假设要找出 X 中分配给聚类 <code>k=0</code> 的所有值，即这些样本在 idx 中的对应值为 0。在 Python 中，可以写为 <code>X[idx == 0]</code>。同样，分配给聚类中心 <code>k=1</code> 的点为 <code>X[idx == 1]</code>
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; 计算 points 的更多提示</b></font></summary>
#                &emsp; &emsp; 可以按如下方式计算 points：<code>points = X[idx == k] </code>
#            </details>
#     </details>
#
#      <details>
#           <summary><font size="2" color="darkblue"><b>计算 centroids[k] 的提示</b></font></summary>
#           &emsp; &emsp; 可以使用 <a href="https://numpy.org/doc/stable/reference/generated/numpy.mean.html">np.mean</a> 求均值。请务必设置参数 <code>axis=0</code>
#           <details>
#               <summary><font size="2" color="blue"><b>&emsp; &emsp; 计算 centroids[k] 的更多提示</b></font></summary>
#               &emsp; &emsp; 可以按如下方式计算 centroids[k]：<code>centroids[k] = np.mean(points, axis = 0)</code>
#           </details>
#     </details>
#
#     </details>
#
# </details>

# %% [markdown]
# 现在运行下面的单元格来检查您的实现。

# %%
K = 3
centroids = compute_centroids(X, idx, K)

print("The centroids are:", centroids)

# UNIT TEST
compute_centroids_test(compute_centroids)

# %% [markdown]
# **预期输出**：
#
# 2.42830111 3.15792418
#
# 5.81350331 2.63365645
#
# 7.11938687 3.6166844

# %% [markdown]
# <a name="2"></a>
# ## 2 - 在示例数据集上运行 K-means
#
# 完成上面的两个函数（`find_closest_centroids` 和 `compute_centroids`）后，下一步是在一个简单的二维数据集上运行 K-means 算法，帮助你理解 K-means 的工作原理。
# * 建议查看下面的函数（`run_kMeans`），了解其工作方式。
# * 请注意，该代码会在循环中调用你实现的两个函数。
#
# 运行以下代码时，它会生成一个可视化结果，逐步展示算法每次迭代的进展。
# * 最终，你的图应类似于图 1 中显示的图。
#
# <img src="images/figure 1.png" width="500" height="500">
#
#
# **注意**：这一部分无需实现任何内容，只需运行下面提供的代码

# %%
# You do not need to implement anything for this part

def run_kMeans(X, initial_centroids, max_iters=10, plot_progress=False):
    """
    Runs the K-Means algorithm on data matrix X, where each row of X
    is a single example
    """
    
    # Initialize values
    m, n = X.shape
    K = initial_centroids.shape[0]
    centroids = initial_centroids
    previous_centroids = centroids    
    idx = np.zeros(m)
    
    # Run K-Means
    for i in range(max_iters):
        
        #Output progress
        print("K-Means iteration %d/%d" % (i, max_iters-1))
        
        # For each example in X, assign it to the closest centroid
        idx = find_closest_centroids(X, centroids)
        
        # Optionally plot progress
        if plot_progress:
            plot_progress_kMeans(X, centroids, previous_centroids, idx, K, i)
            previous_centroids = centroids
            
        # Given the memberships, compute new centroids
        centroids = compute_centroids(X, idx, K)
    plt.show() 
    return centroids, idx

# %%
# Load an example dataset
X = load_data()

# Set initial centroids
initial_centroids = np.array([[3,3],[6,2],[8,5]])
K = 3

# Number of iterations
max_iters = 10

centroids, idx = run_kMeans(X, initial_centroids, max_iters, plot_progress=True)

# %% [markdown]
# <a name="3"></a>
# ## 3 - 随机初始化
#
# 示例数据集的初始聚类中心分配经过专门设计，以便你看到与图 1 相同的图形。在实践中，初始化聚类中心的一种好策略是从训练集中随机选择样本。
#
# 在练习的这一部分，你应理解 `kMeans_init_centroids` 函数的实现方式。
# * 代码首先随机打乱样本索引（使用 `np.random.permutation()`）。
# * 然后，根据索引的随机排列选择前 $K$ 个样本。
#     * 这样既能随机选择样本，又不会有两次选中同一样本的风险。
#
# **注意**：练习的这一部分不需要实现任何内容。

# %%
# You do not need to modify this part

def kMeans_init_centroids(X, K):
    """
    This function initializes K centroids that are to be 
    used in K-Means on the dataset X
    
    Args:
        X (ndarray): Data points 
        K (int):     number of centroids/clusters
    
    Returns:
        centroids (ndarray): Initialized centroids
    """
    
    # Randomly reorder the indices of examples
    randidx = np.random.permutation(X.shape[0])
    
    # Take the first K examples as centroids
    centroids = X[randidx[:K]]
    
    return centroids

# %% [markdown]
# <a name="4"></a>
# ## 4 - 使用 K-means 压缩图像
#
# 在本练习中，你将把 K-means 应用于图像压缩。
#
# * 在图像的直接 24 位颜色表示方式中$^{2}$，每个像素由三个 8 位无符号整数（取值范围为 0 到 255）表示，分别指定红、绿、蓝三种颜色的强度值。这种编码通常称为 RGB 编码。
# * 我们的图像包含数千种颜色，在练习的这一部分，你要将颜色数量减少到 16 种。
# * 通过这种精简，可以高效地表示（压缩）照片。
# * 具体而言，只需存储选中的 16 种颜色的 RGB 值；对于图像中的每个像素，现在只需存储该位置颜色的索引（表示 16 种可能性只需要 4 位）。
#
# 在这一部分，你将使用 K-means 算法选择用于表示压缩图像的 16 种颜色。
# * 具体来说，你会将原始图像中的每个像素视为一个数据样本，并使用 K-means 算法，在三维 RGB 空间中找到最能对像素进行分组（聚类）的 16 种颜色。
# * 计算出图像的聚类中心后，再使用这 16 种颜色替换原始图像中的像素。
#
# <img src="images/figure 2.png" width="500" height="500">
#
# $^{2}$<sub>本练习所用照片由 Frank Wouters 提供，并经其许可使用。</sub>
#
# <a name="4.1"></a>
# ### 4.1 数据集
#
# **加载图像**
#
# 首先，如下所示，使用 `matplotlib` 读入原始图像。

# %%
# Load an image of a bird
original_img = plt.imread('bird_small.png')

# %% [markdown]
# **可视化图像**
#
# 您可以使用下面的代码将刚刚加载的图像可视化。

# %%
# Visualizing the image
plt.imshow(original_img)

# %% [markdown]
# **检查变量的维度**
#
# 和往常一样，您将打印变量的形状，以便进一步熟悉数据。

# %%
print("Shape of original_img is:", original_img.shape)

# %% [markdown]
# 可以看到，这会创建一个三维矩阵 `original_img`，其中：
# * 前两个索引标识像素位置；
# * 第三个索引表示红色、绿色或蓝色。
#
# 例如，`original_img[50, 33, 2]` 给出第 50 行、第 33 列像素的蓝色强度。
#
# #### 处理数据
#
# 要调用 `run_kMeans`，首先需要将矩阵 `original_img` 转换为二维矩阵。
#
# * 下面的代码重塑矩阵 `original_img`，创建一个像素颜色矩阵 $m \times 3$（其中
# $m=16384 = 128\times128$）

# %%
# Divide by 255 so that all values are in the range 0 - 1
original_img = original_img / 255

# Reshape the image into an m x 3 matrix where m = number of pixels
# (in this case m = 128 x 128 = 16384)
# Each row will contain the Red, Green and Blue pixel values
# This gives us our dataset matrix X_img that we will use K-Means on.

X_img = np.reshape(original_img, (original_img.shape[0] * original_img.shape[1], 3))

# %% [markdown]
# <a name="4.2"></a>
# ### 4.2 对图像像素运行 K-Means
#
# 现在，运行下面的单元格，对预处理后的图像执行 K-Means。

# %%
# Run your K-Means algorithm on this data
# You should try different values of K and max_iters here
K = 16                       
max_iters = 10               

# Using the function you have implemented above. 
initial_centroids = kMeans_init_centroids(X_img, K) 

# Run K-Means - this takes a couple of minutes
centroids, idx = run_kMeans(X_img, initial_centroids, max_iters)

# %%
print("Shape of idx:", idx.shape)
print("Closest centroid for the first five elements:", idx[:5])

# %% [markdown]
# <a name="4.3"></a>
# ### 4.3 压缩图像

# %% [markdown]
# 找到用于表示图像的前 $K=16$ 种颜色后，就可以使用 `find_closest_centroids` 函数，将每个像素位置分配给距离最近的质心。
# * 这样便能使用每个像素的质心分配结果来表示原始图像。
# * 请注意，描述图像所需的位数已显著减少。
#     * 原始图像的每个 $128\times128$ 像素位置都需要 24 位，因此总大小为 $128 \times 128 \times 24 = 393,216$ 位。
#     * 新表示法需要一些额外存储空间，以字典形式保存 16 种颜色，每种颜色需要 24 位；但图像本身的每个像素位置只需要 4 位。
#     * 因此，最终使用的位数为 $16 \times 24 + 128 \times 128 \times 4 = 65,920$ 位，相当于将原始图像压缩了约 6 倍。

# %%
# Represent image in terms of indices
X_recovered = centroids[idx, :] 

# Reshape recovered image into proper dimensions
X_recovered = np.reshape(X_recovered, original_img.shape)

# %% [markdown]
# 最后，可以通过仅根据聚类中心分配结果重建图像，查看压缩的效果。
# * 具体来说，可以将每个像素位置替换为分配给它的聚类中心的均值。
# * 图 3 展示了得到的重建结果。尽管生成的图像保留了原图的大部分特征，但也能看到一些压缩伪影。
#
# <img src="images/figure 3.png" width="700" height="700">

# %%
# Display original image
fig, ax = plt.subplots(1,2, figsize=(8,8))
plt.axis('off')

ax[0].imshow(original_img*255)
ax[0].set_title('Original')
ax[0].set_axis_off()


# Display compressed image
ax[1].imshow(X_recovered*255)
ax[1].set_title('Compressed with %d colours'%K)
ax[1].set_axis_off()
